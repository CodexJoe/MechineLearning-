# %% [markdown]
# <a href="https://colab.research.google.com/github/CodexJoe/MechineLearning-/blob/main/TODO_CheckpointANN_completed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
# In this practical, we implement and train a feed-forward neural network (also known as an "MLP" for "multi-layer perceptron") on a dataset called "Fashion MNIST", consisting of small greyscale images of items of fashion.

# %% [markdown]
# # Learning Objectives
#
# * Understand how to use Keras Layers to build a neural network architecture
# * Understand how a model is trained and evaluated
# * Understand the concept of train/validation/test split and why it's useful

# %%
from __future__ import print_function

import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.utils import to_categorical

# %% [markdown]
# # Data
# In this practical, we use the Fashion MNIST dataset consisting of 70,000 greyscale images and their labels. The dataset is divided
#  into 60,000 training images and 10,000 test images. The idea is to train a **classifier** to identify the class value (what type of fashion item it is) given the image. We train and *tune* a model on the 60,000 training images and then evaluate how well it classifies the 10,000 test images that the model did not see during training. This task is an example of a **supervised learning** problem, where we are given both input and labels (targets) to learn from. This is in contrast to **unsupervised learning** where we only have inputs from which to learn patterns or **reinforcement learning** where an agent learns how to maximise a reward signal through interaction with its environment.

# %% [markdown]
# ![Texte alternatif…](https://res.cloudinary.com/practicaldev/image/fetch/s---fNWEeWA--/c_imagga_scale,f_auto,fl_progressive,h_420,q_auto,w_1000/https://raw.githubusercontent.com/zalandoresearch/fashion-mnist/master/doc/img/fashion-mnist-sprite.png)

# %% [markdown]
# # Train/Validation/Test Split
#
# When we build machine learning models, the goal is to build a model that will perform well on future data that we have not seen yet. We say that we want our models to be able to generalise well from whatever training data we can collect and do have available, to whatever data we will be applying them to in future. To do this, we split whatever data we have available into a training set, a validation set and a test set. The idea is that we train our model and use the performance on the validation set to make any adjustments to the model and its hyperparameters, but then we report the final accuracy on the test set. The test set (which we never train on), therefore acts as a proxy for our future data.

# %%
(train_and_validation_images, train_and_validation_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
# Construct a validation set from the last 10000 images and labels from 
# train_and_validation_images and train_and_validation_labels
validation_images = train_and_validation_images[-10000:, :, :]
validation_labels = train_and_validation_labels[-10000:]

# Construct a training set from the first 50000 images and labels.
train_images = train_and_validation_images[:50000, :, :]
train_labels = train_and_validation_labels[:50000]

# %%
text_labels = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure()
random_index = np.random.randint(0, len(train_images))
plt.imshow(train_images[random_index], cmap='gray')
plt.colorbar()
numerical_label = train_labels[random_index]
text_description = text_labels[numerical_label]
plt.title('True Class: {} ("{}")'.format(numerical_label, text_description))

plt.gca().grid(False)

# %%
# Another view, showing 50 randomly selected images at a time
plt.figure(figsize=(20,20))
for i in range(50):
    plt.subplot(5,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    
    img_index = np.random.randint(0, 50000)
    plt.imshow(train_images[img_index], cmap=plt.cm.gray)
    plt.xlabel(text_labels[train_labels[img_index]])

# %% [markdown]
# # Preprocess

# %%
# Flatten

train_images_flatten = train_images.reshape(train_images.shape[0], 784) # 26*26 gives 784
validation_images_flatten = validation_images.reshape(validation_images.shape[0],784)
test_images_flatten = test_images.reshape(test_images.shape[0],784)

# %%
# Normalize

train_images_model = train_images_flatten/255.
validation_images_model = validation_images_flatten/255
test_images_model = test_images_flatten/255 #

# %%
# convert class vectors to binary class matrices
train_labels_categ = keras.utils.to_categorical(train_labels, 10)
validation_labels_categ = keras.utils.to_categorical(validation_labels, 10)
test_labels_categ = keras.utils.to_categorical(test_labels, 10)

# %% [markdown]
# # Train

# %%
batch_size = 128
num_classes = 10
epochs = 40

# Create a sequential model here 


from keras.layers.activation.relu import ReLU
# Defining the model
model = Sequential()
model.add(Dense(256,  activation = 'relu'))
model.add(Dense(128, activation = 'softmax'))
model.add(Dense(10, activation = 'softmax'))

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=["accuracy"])

# %%
history = model.fit(train_images_model, train_labels_categ, validation_data=(validation_images_model,validation_labels_categ ), epochs=epochs)
# Out:
# Epoch 1/40
# 1563/1563 [==============================] - 11s 6ms/step - loss: 1.6395 - accuracy: 0.4504 - val_loss: 1.2982 - val_accuracy: 0.4757
# Epoch 2/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.1761 - accuracy: 0.4841 - val_loss: 1.0922 - val_accuracy: 0.4863
# Epoch 3/40
# 1563/1563 [==============================] - 9s 5ms/step - loss: 1.0403 - accuracy: 0.5184 - val_loss: 1.0083 - val_accuracy: 0.5793
# Epoch 4/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9585 - accuracy: 0.5889 - val_loss: 0.9395 - val_accuracy: 0.6084
# Epoch 5/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8900 - accuracy: 0.6237 - val_loss: 0.8845 - val_accuracy: 0.6175
# Epoch 6/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8387 - accuracy: 0.6562 - val_loss: 0.8479 - val_accuracy: 0.6602
# Epoch 7/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7609 - accuracy: 0.7319 - val_loss: 0.7278 - val_accuracy: 0.7674
# Epoch 8/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6311 - accuracy: 0.7952 - val_loss: 0.6278 - val_accuracy: 0.7895
# Epoch 9/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5555 - accuracy: 0.8097 - val_loss: 0.5624 - val_accuracy: 0.7993
# Epoch 10/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4992 - accuracy: 0.8210 - val_loss: 0.5267 - val_accuracy: 0.8086
# Epoch 11/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4655 - accuracy: 0.8275 - val_loss: 0.5064 - val_accuracy: 0.8183
# Epoch 12/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4414 - accuracy: 0.8360 - val_loss: 0.5059 - val_accuracy: 0.8175
# Epoch 13/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4209 - accuracy: 0.8428 - val_loss: 0.4852 - val_accuracy: 0.8381
# Epoch 14/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3793 - accuracy: 0.8749 - val_loss: 0.4247 - val_accuracy: 0.8644
# Epoch 15/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3410 - accuracy: 0.8883 - val_loss: 0.3994 - val_accuracy: 0.8727
# Epoch 16/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3189 - accuracy: 0.8967 - val_loss: 0.4155 - val_accuracy: 0.8657
# Epoch 17/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3086 - accuracy: 0.8997 - val_loss: 0.3935 - val_accuracy: 0.8763
# Epoch 18/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2960 - accuracy: 0.9029 - val_loss: 0.4010 - val_accuracy: 0.8767
# Epoch 19/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2879 - accuracy: 0.9046 - val_loss: 0.3745 - val_accuracy: 0.8787
# Epoch 20/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2759 - accuracy: 0.9089 - val_loss: 0.3898 - val_accuracy: 0.8811
# Epoch 21/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2717 - accuracy: 0.9102 - val_loss: 0.3727 - val_accuracy: 0.8775
# Epoch 22/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2631 - accuracy: 0.9130 - val_loss: 0.3793 - val_accuracy: 0.8782
# Epoch 23/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2565 - accuracy: 0.9149 - val_loss: 0.3771 - val_accuracy: 0.8810
# Epoch 24/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2507 - accuracy: 0.9168 - val_loss: 0.3866 - val_accuracy: 0.8814
# Epoch 25/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2476 - accuracy: 0.9167 - val_loss: 0.3787 - val_accuracy: 0.8839
# Epoch 26/40
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.2405 - accuracy: 0.9204 - val_loss: 0.3783 - val_accuracy: 0.8818
# Epoch 27/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2370 - accuracy: 0.9204 - val_loss: 0.3854 - val_accuracy: 0.8826
# Epoch 28/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2313 - accuracy: 0.9236 - val_loss: 0.3927 - val_accuracy: 0.8802
# Epoch 29/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2307 - accuracy: 0.9233 - val_loss: 0.3981 - val_accuracy: 0.8808
# Epoch 30/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2256 - accuracy: 0.9251 - val_loss: 0.3821 - val_accuracy: 0.8850
# Epoch 31/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2219 - accuracy: 0.9259 - val_loss: 0.3809 - val_accuracy: 0.8835
# Epoch 32/40
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.2158 - accuracy: 0.9292 - val_loss: 0.3830 - val_accuracy: 0.8828
# Epoch 33/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2126 - accuracy: 0.9295 - val_loss: 0.3906 - val_accuracy: 0.8812
# Epoch 34/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2122 - accuracy: 0.9291 - val_loss: 0.3870 - val_accuracy: 0.8832
# Epoch 35/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2099 - accuracy: 0.9310 - val_loss: 0.3887 - val_accuracy: 0.8819
# Epoch 36/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2031 - accuracy: 0.9313 - val_loss: 0.3955 - val_accuracy: 0.8808
# Epoch 37/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2034 - accuracy: 0.9324 - val_loss: 0.4039 - val_accuracy: 0.8811
# Epoch 38/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1993 - accuracy: 0.9345 - val_loss: 0.4145 - val_accuracy: 0.8779
# Epoch 39/40
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1956 - accuracy: 0.9349 - val_loss: 0.3923 - val_accuracy: 0.8855
# Epoch 40/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.1959 - accuracy: 0.9359 - val_loss: 0.4076 - val_accuracy: 0.8837

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(train_images_model, train_labels_categ,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(validation_images_model, validation_labels_categ))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.6065 - accuracy: 0.7825 - val_loss: 0.5144 - val_accuracy: 0.8005
# Epoch 2/40
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.4274 - accuracy: 0.8447 - val_loss: 0.3986 - val_accuracy: 0.8512
# Epoch 3/40
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.3859 - accuracy: 0.8570 - val_loss: 0.3530 - val_accuracy: 0.8736
# Epoch 4/40
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.3625 - accuracy: 0.8678 - val_loss: 0.3568 - val_accuracy: 0.8708
# Epoch 5/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.3459 - accuracy: 0.8729 - val_loss: 0.3379 - val_accuracy: 0.8749
# Epoch 6/40
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.3308 - accuracy: 0.8775 - val_loss: 0.3326 - val_accuracy: 0.8784
# Epoch 7/40
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.3223 - accuracy: 0.8819 - val_loss: 0.3557 - val_accuracy: 0.8733
# Epoch 8/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.3121 - accuracy: 0.8853 - val_loss: 0.3444 - val_accuracy: 0.8725
# Epoch 9/40
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.3039 - accuracy: 0.8883 - val_loss: 0.3291 - val_accuracy: 0.8868
# Epoch 10/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2988 - accuracy: 0.8898 - val_loss: 0.3158 - val_accuracy: 0.8900
# Epoch 11/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2896 - accuracy: 0.8947 - val_loss: 0.3294 - val_accuracy: 0.8834
# Epoch 12/40
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.2847 - accuracy: 0.8949 - val_loss: 0.3375 - val_accuracy: 0.8841
# Epoch 13/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2797 - accuracy: 0.8970 - val_loss: 0.3241 - val_accuracy: 0.8843
# Epoch 14/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2740 - accuracy: 0.8997 - val_loss: 0.3159 - val_accuracy: 0.8929
# Epoch 15/40
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.2711 - accuracy: 0.9000 - val_loss: 0.3132 - val_accuracy: 0.8919
# Epoch 16/40
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.2651 - accuracy: 0.9018 - val_loss: 0.3313 - val_accuracy: 0.8895
# Epoch 17/40
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.2620 - accuracy: 0.9030 - val_loss: 0.3437 - val_accuracy: 0.8854
# Epoch 18/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2594 - accuracy: 0.9039 - val_loss: 0.3239 - val_accuracy: 0.8916
# Epoch 19/40
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.2544 - accuracy: 0.9056 - val_loss: 0.3219 - val_accuracy: 0.8929
# Epoch 20/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2509 - accuracy: 0.9061 - val_loss: 0.3667 - val_accuracy: 0.8912
# Epoch 21/40
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.2465 - accuracy: 0.9087 - val_loss: 0.3185 - val_accuracy: 0.8922
# Epoch 22/40
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.2454 - accuracy: 0.9092 - val_loss: 0.3337 - val_accuracy: 0.8887
# Epoch 23/40
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.2473 - accuracy: 0.9092 - val_loss: 0.3455 - val_accuracy: 0.8857
# Epoch 24/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2395 - accuracy: 0.9129 - val_loss: 0.3337 - val_accuracy: 0.8929
# Epoch 25/40
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.2347 - accuracy: 0.9128 - val_loss: 0.3351 - val_accuracy: 0.8919
# Epoch 26/40
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.2338 - accuracy: 0.9125 - val_loss: 0.3455 - val_accuracy: 0.8954
# Epoch 27/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2331 - accuracy: 0.9142 - val_loss: 0.3412 - val_accuracy: 0.8949
# Epoch 28/40
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.2317 - accuracy: 0.9156 - val_loss: 0.3435 - val_accuracy: 0.8948
# Epoch 29/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2278 - accuracy: 0.9153 - val_loss: 0.3701 - val_accuracy: 0.8893
# Epoch 30/40
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.2275 - accuracy: 0.9163 - val_loss: 0.3482 - val_accuracy: 0.8935
# Epoch 31/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2254 - accuracy: 0.9160 - val_loss: 0.3502 - val_accuracy: 0.8906
# Epoch 32/40
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.2236 - accuracy: 0.9164 - val_loss: 0.3428 - val_accuracy: 0.8934
# Epoch 33/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2223 - accuracy: 0.9176 - val_loss: 0.3486 - val_accuracy: 0.8938
# Epoch 34/40
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.2199 - accuracy: 0.9201 - val_loss: 0.3532 - val_accuracy: 0.8939
# Epoch 35/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2171 - accuracy: 0.9192 - val_loss: 0.3738 - val_accuracy: 0.8923
# Epoch 36/40
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.2180 - accuracy: 0.9212 - val_loss: 0.3642 - val_accuracy: 0.8917
# Epoch 37/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2141 - accuracy: 0.9211 - val_loss: 0.3607 - val_accuracy: 0.8936
# Epoch 38/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2126 - accuracy: 0.9212 - val_loss: 0.3549 - val_accuracy: 0.8930
# Epoch 39/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2111 - accuracy: 0.9227 - val_loss: 0.3762 - val_accuracy: 0.8887
# Epoch 40/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.2121 - accuracy: 0.9224 - val_loss: 0.4072 - val_accuracy: 0.8938

# %% [markdown]
# # Test

# %%
score = model.evaluate(test_images_model, test_labels_categ, verbose=0)
print('Test accuracy:', score[1])
# You should be able to get,at least, 88% accuracy
# Out:
# Test accuracy: 0.8741000294685364

# %%
test_logits = model.predict(test_images_flatten)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
test_logits
# Out:
# array([[2.6727835e-06, 6.0342149e-06, 9.4609553e-05, ..., 1.9213308e-03,
#         6.5067245e-05, 9.9741668e-01],
#        [1.4893833e-03, 1.8015497e-04, 9.8429507e-01, ..., 1.5739042e-08,
#         3.8845232e-05, 1.4356674e-06],
#        [9.7209075e-04, 9.9381506e-01, 3.1594920e-09, ..., 1.3314224e-11,
#         3.7946314e-13, 2.2681730e-10],
#        ...,
#        [3.8695394e-03, 1.1997407e-12, 5.5999709e-07, ..., 3.4749162e-05,
#         9.8875117e-01, 1.4659608e-06],
#        [9.7209075e-04, 9.9381506e-01, 3.1594920e-09, ..., 1.3314224e-11,
#         3.7946314e-13, 2.2681730e-10],
#        [6.2408202e-05, 4.7232229e-06, 3.2106016e-04, ..., 6.5590715e-04,
#         6.2635023e-05, 1.2502591e-04]], dtype=float32)

# %%
test_predictions = np.argmax(test_logits, axis=1)

# %%
test_predictions
# Out:
# array([9, 2, 1, ..., 8, 1, 5])

# %%
model.evaluate(test_images_model, test_labels_categ)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4299 - accuracy: 0.8741
# [0.42994818091392517, 0.8741000294685364]

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    
    img_index = np.random.randint(0, 10000)
    plt.imshow(test_images[img_index], cmap=plt.cm.gray)
    
    actual_label = int(test_labels[img_index])
    predicted_label = int(test_predictions[img_index])
    
    plt.xlabel("Actual: {} ({})\n Predicted: {} ({})".format(
        actual_label, text_labels[actual_label], predicted_label, text_labels[predicted_label]
    ))
    
plt.tight_layout()
plt.show()
